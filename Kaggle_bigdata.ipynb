# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d shiekhburhan/face-mask-dataset
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/shiekhburhan/face-mask-dataset
# License(s): CC0-1.0
# Downloading face-mask-dataset.zip to /content
# 100% 2.32G/2.33G [00:39<00:00, 59.1MB/s]
# 100% 2.33G/2.33G [00:39<00:00, 63.6MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/face-mask-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
