# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/data/penguins.csv')

# %%
data=data[data.species!='Chinstrap']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 265 entries, 0 to 264
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         265 non-null    int64
#  1   species            265 non-null    object
#  2   island             265 non-null    object
#  3   bill_length_mm     265 non-null    float64
#  4   bill_depth_mm      265 non-null    float64
#  5   flipper_length_mm  265 non-null    int64
#  6   body_mass_g        265 non-null    int64
#  7   sex                265 non-null    object
#  8   year               265 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 20.7+ KB

# %%
data
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen            36.7           19.3
# 4             4  Adelie  Torgersen            39.3           20.6
# ..          ...     ...        ...             ...            ...
# 260         260  Gentoo     Biscoe            47.2           13.7
# 261         261  Gentoo     Biscoe            46.8           14.3
# 262         262  Gentoo     Biscoe            50.4           15.7
# 263         263  Gentoo     Biscoe            45.2           14.8
# 264         264  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                  181         3750    male  2007
# 1                  186         3800  female  2007
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  265.000000      265.000000     265.000000         265.000000
# mean   132.000000       42.750566      16.842642         202.286792
# std     76.643112        5.214804       2.009775          15.018953
# min      0.000000       32.100000      13.100000         172.000000
# 25%     66.000000       38.600000      15.000000         190.000000
# 50%    132.000000       42.000000      17.000000         198.000000
# 75%    198.000000       46.800000      18.500000         215.000000
# max    264.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   265.000000   265.000000
# mean   4328.679245  2008.060377
# std     839.748875     0.800175
# min    2850.000000  2007.000000
# 25%    3600.000000  2007.000000
# 50%    4300.000000  2008.000000
# 75%    5000.000000  2009.000000
# max    6300.000000  2009.000000

# %%
data.iloc[:,[3,4,5,6,8]].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.543166           0.870276
# bill_depth_mm           -0.543166       1.000000          -0.634645
# flipper_length_mm        0.870276      -0.634645           1.000000
# body_mass_g              0.876786      -0.483227           0.884427
# year                     0.063172      -0.033169           0.125260
#
#                    body_mass_g      year
# bill_length_mm        0.876786  0.063172
# bill_depth_mm        -0.483227 -0.033169
# flipper_length_mm     0.884427  0.125260
# body_mass_g           1.000000  0.005869
# year                  0.005869  1.000000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'bill_length_mm'}>],
#        [<Axes: title={'center': 'bill_depth_mm'}>,
#         <Axes: title={'center': 'flipper_length_mm'}>],
#        [<Axes: title={'center': 'body_mass_g'}>,
#         <Axes: title={'center': 'year'}>]], dtype=object)

# %%
sns.catplot(x='bill_length_mm',y='bill_depth_mm', hue='species',data=data)

# %%
sns.catplot(x='bill_length_mm',y='flipper_length_mm', hue='species',data=data)

# %%
sns.catplot(x='bill_length_mm',y='body_mass_g', hue='species',data=data)

# %%
sns.catplot(x='bill_depth_mm',y='flipper_length_mm', hue='species',data=data)

# %%
X=data[['bill_depth_mm','flipper_length_mm']]
X
# Out:
#      bill_depth_mm  flipper_length_mm
# 0             18.7                181
# 1             17.4                186
# 2             18.0                195
# 3             19.3                193
# 4             20.6                190
# ..             ...                ...
# 260           13.7                214
# 261           14.3                215
# 262           15.7                222
# 263           14.8                212
# 264           16.1                213
#
# [265 rows x 2 columns]

# %%
y=data['species'].map({'Adelie':0,'Gentoo':1})
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 260    1
# 261    1
# 262    1
# 263    1
# 264    1
# Name: species, Length: 265, dtype: int64

# %%
X.shape
# Out:
# (265, 2)

# %%
y.shape
# Out:
# (265,)

# %%
def sigmoid(z):
  return 1/(1+np.exp(-z))

# %%
sigmoid(np.array([1,2,3]))
# Out:
# array([0.73105858, 0.88079708, 0.95257413])

# %%
def cost_function(y_true,y_pred):
  m =len(data)
  return -np.sum(y_true*np.log(y_pred)+(1-y_true)*np.log(1-y_pred))/m

# %%
# cost function

# %%
def gredient_descent(X,y,W,b,learning_rate):
  linear_pred=np.dot(X,W)+b
  predictions = sigmoid(linear_pred)
  dw = (1/X.shape[0])* np.dot(X.T,(predictions-y))
  db =(1/X.shape[0])*np.dot(predictions-y)
  W= W-learning_rate*dw
  b= b-learning_rate*db
  return W,b

  # dw=np.mean(np.dot(X.T,(y_pred-y_true)))
  # db= np.sum(y_pred-y_true)
  # W= y_true -dw*L
  # b= y_true-db*L
  # return w ,b

# %%
def predict(W,b,x):
  linear_pred=np.dot(X,W)+b
  y_pred= sigmoid(linear_pred)
  pred_class = [0 if y<=0 else 1 for y in y_pred]
  return pred_class

# %%
def accuracy(y_pred,y_test):
  return np.sum(y_pred==y_test)/len(y_test)
