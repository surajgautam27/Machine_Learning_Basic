# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_f={
    's.no':['1','2','3'],
    'Name':['ram','shyam','hari'],
    'Age':[20,30,40]
}
data = pd.DataFrame(data_f)
data
# Out:
#   s.no   Name  Age
# 0    1    ram   20
# 1    2  shyam   30
# 2    3   hari   40

# %%
data2=pd.Series(['Ram','shyam','Hari'])
data2
# Out:
# 0      Ram
# 1    shyam
# 2     Hari
# dtype: object

# %%
data
# Out:
#   s.no   Name  Age
# 0    1    ram   20
# 1    2  shyam   30
# 2    3   hari   40

# %%
data['Name']
# Out:
# 0      ram
# 1    shyam
# 2     hari
# Name: Name, dtype: object

# %%
data[['Name','Age']]
# Out:
#     Name  Age
# 0    ram   20
# 1  shyam   30
# 2   hari   40

# %%
data['Address']=['hyd','bang','del']
data
# Out:
#   s.no   Name  Age Address
# 0    1    ram   20     hyd
# 1    2  shyam   30    bang
# 2    3   hari   40     del

# %%
data['Email']=data['Name']+'_'+data['Address']+'@gmail.com'
data
# Out:
#   s.no   Name  Age Address                 Email
# 0    1    ram   20     hyd     ram_hyd@gmail.com
# 1    2  shyam   30    bang  shyam_bang@gmail.com
# 2    3   hari   40     del    hari_del@gmail.com

# %%
data
# Out:
#   s.no   Name  Age Address                 Email
# 0    1    ram   20     hyd     ram_hyd@gmail.com
# 1    2  shyam   30    bang  shyam_bang@gmail.com
# 2    3   hari   40     del    hari_del@gmail.com

# %%
data[(data['Age']>10) & (data['Address']=='hyd')]
# Out:
#   s.no Name  Age Address              Email
# 0    1  ram   20     hyd  ram_hyd@gmail.com

# %%
data['Age']
# Out:
# 0    20
# 1    30
# 2    40
# Name: Age, dtype: int64

# %%
data[(data['Age']<20) | (data['Address']=='hyd')]
# Out:
#   s.no Name  Age Address              Email
# 0    1  ram   20     hyd  ram_hyd@gmail.com

# %%
data.loc[2]
# Out:
# s.no                        3
# Name                     hari
# Age                        40
# Address                   del
# Email      hari_del@gmail.com
# Name: 2, dtype: object

# %%
data.loc[0:2]
# Out:
#   s.no   Name  Age Address                 Email
# 0    1    ram   20     hyd     ram_hyd@gmail.com
# 1    2  shyam   30    bang  shyam_bang@gmail.com
# 2    3   hari   40     del    hari_del@gmail.com

# %%
data.iloc[0:2]
# Out:
#   s.no   Name  Age Address                 Email
# 0    1    ram   20     hyd     ram_hyd@gmail.com
# 1    2  shyam   30    bang  shyam_bang@gmail.com

# %%
data.iloc[0:2,0:2]
# Out:
#   s.no   Name
# 0    1    ram
# 1    2  shyam

# %%
data.loc[0:2,['Name','Age','Address']]
# Out:
#     Name  Age Address
# 0    ram   20     hyd
# 1  shyam   30    bang
# 2   hari   40     del

# %%
df=pd.read_csv('/content/drive/MyDrive/data/data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df1=df.dropna()
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.loc[168]
# Out:
# Duration     75.0
# Pulse       125.0
# Maxpulse    150.0
# Calories    330.4
# Name: 168, dtype: float64

# %%
df.iloc[163]
# Out:
# Duration     75.0
# Pulse       125.0
# Maxpulse    150.0
# Calories    330.4
# Name: 168, dtype: float64

# %%
df.reset_index()
# Out:
#      index  Duration  Pulse  Maxpulse  Calories
# 0        0        60    110       130     409.1
# 1        1        60    117       145     479.0
# 2        2        60    103       135     340.0
# 3        3        45    109       175     282.4
# 4        4        45    117       148     406.0
# ..     ...       ...    ...       ...       ...
# 159    164        60    105       140     290.8
# 160    165        60    110       145     300.0
# 161    166        60    115       145     310.2
# 162    167        75    120       150     320.4
# 163    168        75    125       150     330.4
#
# [164 rows x 5 columns]

# %%
df.reset_index(drop=True)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 159        60    105       140     290.8
# 160        60    110       145     300.0
# 161        60    115       145     310.2
# 162        75    120       150     320.4
# 163        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.drop(columns=['Duration'])
# Out:
#      Pulse  Maxpulse  Calories
# 0      110       130     409.1
# 1      117       145     479.0
# 2      103       135     340.0
# 3      109       175     282.4
# 4      117       148     406.0
# ..     ...       ...       ...
# 164    105       140     290.8
# 165    110       145     300.0
# 166    115       145     310.2
# 167    120       150     320.4
# 168    125       150     330.4
#
# [164 rows x 3 columns]

# %%
df.describe()
# Out:
#          Duration       Pulse   Maxpulse     Calories
# count  164.000000  164.000000  164.00000   164.000000
# mean    64.146341  107.676829  134.27439   375.790244
# std     42.888820   14.637516   16.58306   266.379919
# min     15.000000   80.000000  100.00000    50.300000
# 25%     45.000000  100.000000  124.00000   250.925000
# 50%     60.000000  105.500000  131.00000   318.600000
# 75%     60.000000  111.000000  143.00000   387.600000
# max    300.000000  159.000000  184.00000  1860.400000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='hist', subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
df.plot(kind='bar', subplots=True)
# Out:
# array([<Axes: title={'center': 'Duration'}>,
#        <Axes: title={'center': 'Pulse'}>,
#        <Axes: title={'center': 'Maxpulse'}>,
#        <Axes: title={'center': 'Calories'}>], dtype=object)

# %%
df.columns
for col in df.columns:
  plt.hist(col)

# %%
for col in df.columns:
 plt.plot(col)

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.160661  0.005679  0.922717
# Pulse    -0.160661  1.000000  0.784631  0.025121
# Maxpulse  0.005679  0.784631  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
df.plot(x='Duration',y='Calories',kind='scatter')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
df.plot(x='Duration',y='Maxpulse',kind='scatter')
# Out:
# <Axes: xlabel='Duration', ylabel='Maxpulse'>

# %%
# df.to_excel('/content/drive/MyDrive/data.xlsx')
